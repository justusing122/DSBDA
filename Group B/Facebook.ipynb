# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset_Facebook.csv",sep=';')
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
display(df)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
column1 = df.iloc[:250]
column1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 245            130791   Photo         1           7             2         13
# 246            130791   Photo         2           7             2          8
# 247            129600   Photo         2           7             1         12
# 248            129600   Photo         3           7             1          6
# 249            129600   Photo         2           7             7         11
#
# ...

# %%
column2= df.iloc[250:500]
column2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 250            129600   Photo         1           7             7          6
# 251            129600   Photo         1           7             6         11
# 252            129600   Photo         3           7             6          5
# 253            129600  Status         2           7             5         12
# 254            129600   Photo         3           7             5          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df1 = pd.concat([column1,column2])
df1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df1.sort_values('Category',ascending=False)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 108            136736  Photo         3          10             7          9
# 322            123047  Photo         3           6             2          5
# 331            119198  Photo         3           5             3          5
# 330            120050  Photo         3           5             3         12
# 329            120050  Photo         3           5             4          4
# ..                ...    ...       ...         ...           ...        ...
# 111            136736  Photo         1          10             6          8
# 110            136736  Photo         1          10             6         10
# 339            117764  Photo         1           5             4         10
# 105            137020  Photo         1          10             2          4
# 250            129600  Photo         1           7             7          6
#
# ...

# %%
df1.sort_values('Category',ascending=True)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 128            136393  Photo         1          10             6         13
# 144            136013  Photo         1          10             2          3
# 145            136013  Photo         1          10             1         10
# 402            107907  Photo         1           4             3          4
# 401            107907  Photo         1           4             3         13
# ..                ...    ...       ...         ...           ...        ...
# 356            116435  Photo         3           5             1         13
# 359            116091  Photo         3           5             7          2
# 361            116091  Photo         3           5             6          3
# 143            136013  Photo         3          10             2         10
# 162            135617  Photo         3           9             6         10
#
# ...

# %%
df1.transpose()
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
table = pd.pivot_table(df1,index=['Type','Category'],values='comment')

# %%
table
# Out:
#                    comment
# Type   Category
# Link   1          2.900000
#        2          2.000000
#        3          2.000000
# Photo  1          5.897297
#        2         11.692308
#        3          6.913333
# Status 1          4.333333
#        2          9.921053
#        3          2.750000
# Video  1         12.285714

# %%
df3 = pd.DataFrame(column1)
df4 = pd.DataFrame(column2)

newdf = df3.merge(df4, how='outer')

print(newdf)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
table1 = pd.pivot_table(newdf,index=['Type','Category'],values='comment')

# %%
table1
# Out:
#                    comment
# Type   Category
# Link   1          2.900000
#        2          2.000000
#        3          2.000000
# Photo  1          5.897297
#        2         11.692308
#        3          6.913333
# Status 1          4.333333
#        2          9.921053
#        3          2.750000
# Video  1         12.285714

# %%
df5 = pd.DataFrame(column1)
df6 = pd.DataFrame(column2)

newdf1 = df5.merge(df6,on='Type', how='right')

print(newdf1)
# Out:
#        Page total likes_x   Type  Category_x  Post Month_x  Post Weekday_x  \
# 0                  139441  Photo           2            12               4
# 1                  139441  Photo           3            12               3
# 2                  139441  Photo           2            12               2
# 3                  139441  Photo           2            12               2
# 4                  139441  Photo           3            12               1
# ...                   ...    ...         ...           ...             ...
# 45644              130791  Photo           1             7               2
# 45645              130791  Photo           2             7               2
# 45646              129600  Photo           2             7               1
# 45647              129600  Photo           3             7               1
# 45648              129600  Photo           2             7               7
#
#        Post Hour_x  Paid_x  Lifetime Post Total Reach_x  \
# ...

# %%
newdf1
# Out:
#        Page total likes_x   Type  Category_x  Post Month_x  Post Weekday_x  \
# 0                  139441  Photo           2            12               4
# 1                  139441  Photo           3            12               3
# 2                  139441  Photo           2            12               2
# 3                  139441  Photo           2            12               2
# 4                  139441  Photo           3            12               1
# ...                   ...    ...         ...           ...             ...
# 45644              130791  Photo           1             7               2
# 45645              130791  Photo           2             7               2
# 45646              129600  Photo           2             7               1
# 45647              129600  Photo           3             7               1
# 45648              129600  Photo           2             7               7
#
#        Post Hour_x  Paid_x  Lifetime Post Total Reach_x  \
# ...

# %%
col1 = df.loc[:10,['Type','Category','Lifetime Post Consumers']]
col1
# Out:
#       Type  Category  Lifetime Post Consumers
# 0    Photo         2                      109
# 1   Status         2                     1361
# 2    Photo         3                      113
# 3    Photo         2                      790
# 4    Photo         2                      410
# 5   Status         2                     1073
# 6    Photo         3                      265
# 7    Photo         3                      232
# 8   Status         2                     1407
# 9    Photo         3                      183
# 10  Status         2                     4100

# %%
col2 = df.loc[:10,['Type','Post Month','Lifetime Post Total Reach']]
col2
# Out:
#       Type  Post Month  Lifetime Post Total Reach
# 0    Photo          12                       2752
# 1   Status          12                      10460
# 2    Photo          12                       2413
# 3    Photo          12                      50128
# 4    Photo          12                       7244
# 5   Status          12                      10472
# 6    Photo          12                      11692
# 7    Photo          12                      13720
# 8   Status          12                      11844
# 9    Photo          12                       4694
# 10  Status          12                      21744

# %%
d1 = pd.DataFrame(col1)
d2 = pd.DataFrame(col2)

newdf5 = d1.merge(d2,on='Type', how='inner')
newdf5 = newdf5.drop_duplicates(subset='Type')
newdf5
# Out:
#       Type  Category  Lifetime Post Consumers  Post Month  \
# 0    Photo         2                      109          12
# 49  Status         2                     1361          12
#
#     Lifetime Post Total Reach
# 0                        2752
# 49                      10460

# %%
d3 = pd.DataFrame(col1)
d4 = pd.DataFrame(col2)

newdf6 = d3.merge(d4,on = 'Type', how='left')
newdf6
# Out:
#       Type  Category  Lifetime Post Consumers  Post Month  \
# 0    Photo         2                      109          12
# 1    Photo         2                      109          12
# 2    Photo         2                      109          12
# 3    Photo         2                      109          12
# 4    Photo         2                      109          12
# ..     ...       ...                      ...         ...
# 60   Photo         3                      183          12
# 61  Status         2                     4100          12
# 62  Status         2                     4100          12
# 63  Status         2                     4100          12
# 64  Status         2                     4100          12
#
#     Lifetime Post Total Reach
# 0                        2752
# 1                        2413
# 2                       50128
# 3                        7244
# 4                       11692
# ..                        ...
# 60                       4694
# ...
